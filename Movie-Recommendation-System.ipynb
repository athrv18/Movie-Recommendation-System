# %% [markdown]
# # **Movie Recommendation System**

# %% [markdown]
# Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# Dataset

# %%
df = pd.read_csv("movies_metadata.csv")

# %% [markdown]
# Head

# %%
df.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# ...

# %% [markdown]
# Total Columns

# %%
df.columns
# Out:
# Index(['adult', 'belongs_to_collection', 'budget', 'genres', 'homepage', 'id',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'video',
#        'vote_average', 'vote_count'],
#       dtype='object')

# %% [markdown]
# Info

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45466 non-null  object
#  1   belongs_to_collection  4494 non-null   object
#  2   budget                 45466 non-null  object
#  3   genres                 45466 non-null  object
#  4   homepage               7782 non-null   object
#  5   id                     45466 non-null  object
#  6   imdb_id                45449 non-null  object
#  7   original_language      45455 non-null  object
#  8   original_title         45466 non-null  object
#  9   overview               44512 non-null  object
#  10  popularity             45461 non-null  object
#  11  poster_path            45080 non-null  object
#  12  production_companies   45463 non-null  object
#  13  production_countries   45463 non-null  object
# ...

# %% [markdown]
# Shape

# %%
df.shape
# Out:
# (45466, 24)

# %% [markdown]
# Null values

# %%
df.isnull().sum()
# Out:
# adult                        0
# belongs_to_collection    40972
# budget                       0
# genres                       0
# homepage                 37684
# id                           0
# imdb_id                     17
# original_language           11
# original_title               0
# overview                   954
# popularity                   5
# poster_path                386
# production_companies         3
# production_countries         3
# release_date                87
# revenue                      6
# runtime                    263
# spoken_languages             6
# status                      87
# tagline                  25054
# title                        6
# video                        6
# vote_average                 6
# vote_count                   6
# dtype: int64

# %% [markdown]
# Duplicate values

# %%
df = df.drop_duplicates().reset_index(drop=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Selected Columns for used

# %%
df = df[["title", "overview", "genres", "tagline", "vote_average", "popularity"]]

# %% [markdown]
# Columns DataFrame

# %%
df
# Out:
#                              title  \
# 0                        Toy Story
# 1                          Jumanji
# 2                 Grumpier Old Men
# 3                Waiting to Exhale
# 4      Father of the Bride Part II
# ...                            ...
# 45448                       Subdue
# 45449          Century of Birthing
# 45450                     Betrayal
# 45451             Satan Triumphant
# 45452                     Queerama
#
#                                                 overview  \
# 0      Led by Woody, Andy's toys live happily in his ...
# 1      When siblings Judy and Peter discover an encha...
# 2      A family wedding reignites the ancient feud be...
# 3      Cheated on, mistreated and stepped on, the wom...
# 4      Just when George Banks has recovered from his ...
# ...                                                  ...
# 45448        Rising and falling between a man and woman.
# 45449  An artist struggles to finish his work while a...
# ...

# %% [markdown]
# DataFrame Null Vlaues

# %%
df.isnull().sum()
# Out:
# title               6
# overview          954
# genres              0
# tagline         25045
# vote_average        6
# popularity          5
# dtype: int64

# %% [markdown]
# Remove "title" Null values from DF

# %%
df = df.dropna(subset=["title"])

# %% [markdown]
# Empty Space for "overview"

# %%
df["overview"] = df["overview"].fillna("")

# %% [markdown]
# Gets the genres of the first row

# %%
df.iloc[0]["genres"]
# Out:
# "[{'id': 16, 'name': 'Animation'}, {'id': 35, 'name': 'Comedy'}, {'id': 10751, 'name': 'Family'}]"

# %% [markdown]
# Extract "genres"
#
#
# ast = Abstract Syntax Trees.

# %%
import ast

df["genres"] = df["genres"].apply(
    lambda x: " ".join(i["name"] for i in ast.literal_eval(x))
)

# %% [markdown]
# Empty Space for "tagline"

# %%
df["tagline"] = df["tagline"].fillna("")

# %% [markdown]
# Null values for "title"

# %%
df.isnull().sum()
# Out:
# title               0
# overview            0
# genres              0
# tagline         25039
# vote_average        0
# popularity          0
# dtype: int64

# %% [markdown]
# Combines "overview" + "genres" + "tagline"

# %%
df["tags"] = df["overview"] + " " + df["genres"] + " " + df["tagline"]
df.head()
# Out:
#                          title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                             overview  \
# 0  Led by Woody, Andy's toys live happily in his ...
# 1  When siblings Judy and Peter discover an encha...
# 2  A family wedding reignites the ancient feud be...
# 3  Cheated on, mistreated and stepped on, the wom...
# 4  Just when George Banks has recovered from his ...
#
#                      genres  \
# 0   Animation Comedy Family
# 1  Adventure Fantasy Family
# 2            Romance Comedy
# 3      Comedy Drama Romance
# 4                    Comedy
#
#                                              tagline  vote_average popularity  \
# 0                                                              7.7  21.946943
# 1          Roll the dice and unleash the excitement!           6.9  17.015539
# ...

# %% [markdown]
# .
#
#
#
#
#
# .

# %% [markdown]
# # NLP Text Preprocessing

# %% [markdown]
# tag 0th info

# %%
df["tags"][0]
# Out:
# "Led by Woody, Andy's toys live happily in his room until Andy's birthday brings Buzz Lightyear onto the scene. Afraid of losing his place in Andy's heart, Woody plots against Buzz. But when circumstances separate Buzz and Woody from their owner, the duo eventually learns to put aside their differences. Animation Comedy Family "

# %% [markdown]
# NLTK = Natural Language Toolkit

# %%
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import re

# %% [markdown]
# Download NLTK tools

# %%
nltk.download("stopwords")
nltk.download("punkt")
nltk.download("wordnet")
nltk.download("omw-1.4")
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# True

# %% [markdown]
# Remove Stopwords

# %%
stop_words = set(stopwords.words("english"))
lemmatizer = WordNetLemmatizer()

# %% [markdown]
# Tokenization

# %%
def prepocess_text(text):

  #lowercase
  text = str(text).lower()

  #removed the punctuations
  text = re.sub(r"a-zA-Z\s", "", text)

  #words split
  words = text.split()

  #remove stopwords
  words = [word for word in words if word not in stop_words]

  #lemmatization
  words = [lemmatizer.lemmatize(word) for word in words]

  #join the words
  return " ".join(words)

# %% [markdown]
# Preprocess text = "tags"

# %%
df["tags"] = df["tags"].apply(prepocess_text)

# %%
df["tags"] [1]
# Out:
# "sibling judy peter discover enchanted board game open door magical world, unwittingly invite alan -- adult who's trapped inside game 26 year -- living room. alan's hope freedom finish game, prof risky three find running giant rhinoceroses, evil monkey terrifying creatures. adventure fantasy family roll dice unleash excitement!"

# %% [markdown]
# .
#
#
#
#
#
# .

# %% [markdown]
# # Text Vectorization

# %% [markdown]
# Reset Index

# %%
df = df.reset_index(drop = True)

# %% [markdown]
# Indices

# %%
indices = pd.Series(df.index, index = df["title"]).drop_duplicates()
indices
# Out:
# title
# Toy Story                          0
# Jumanji                            1
# Grumpier Old Men                   2
# Waiting to Exhale                  3
# Father of the Bride Part II        4
#                                ...
# Subdue                         45442
# Century of Birthing            45443
# Betrayal                       45444
# Satan Triumphant               45445
# Queerama                       45446
# Length: 45447, dtype: int64

# %% [markdown]
# Tf-idf Vectrorization

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
tfidf = TfidfVectorizer(max_features=50000,
                        ngram_range=(1,2),
                        stop_words = "english")

# %% [markdown]
# Matrix

# %%
tfidf_matrix = tfidf.fit_transform(df["tags"])
tfidf_matrix
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 1582161 stored elements and shape (45447, 50000)>

# %% [markdown]
# .
#
#
#
# .

# %% [markdown]
# # Cosine Similarity

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
def recommend(title, n = 10):
  if title not in indices:
    return ["Movie not found"]

  idx = indices[title]
  sim_score = cosine_similarity(tfidf_matrix[idx], tfidf_matrix).flatten()
  similar_idx = sim_score.argsort()[::-1][1:n+1]
  return df["title"].iloc[similar_idx]

# %%
recommend("Avenger")
# Out:
# 41886     Dexter's Laboratory: Ego Trip
# 26634                       Man on Fire
# 4367                             D.O.A.
# 5054                          Hopscotch
# 216                            The Cure
# 871              The Philadelphia Story
# 7842     Now You See Him, Now You Don't
# 7871                       The Escapist
# 25089                  Hit by Lightning
# 18327              Ladies vs Ricky Bahl
# Name: title, dtype: object

# %%
recommend("Avatar")
# Out:
# 26547                                      Avatar 2
# 13883                          The Inhabited Island
# 26553                                Thor: Ragnarok
# 43431                        Moontrap: Target Earth
# 6414     Lara Croft Tomb Raider: The Cradle of Life
# 2457                                     The Matrix
# 21567                The Secret of the Third Planet
# 28633                          Stand by Me Doraemon
# 14119                          The Three Musketeers
# 20372                                        Désiré
# Name: title, dtype: object

# %% [markdown]
# .
#
# .

# %% [markdown]
# # **Testing and making the pickle file**

# %%
import pickle

pickle.dump(tfidf_matrix, open("tfidf_matrix.pkl", "wb"))

pickle.dump(indices, open("indices.pkl", "wb"))

pickle.dump(df, open("df.pkl", "wb"))

pickle.dump(tfidf, open("tfidf.pkl", "wb"))
